# %%
import requests
from bs4 import BeautifulSoup
news=requests.get("https://ekantipur.com/news")
soup=BeautifulSoup(news.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
articles=soup.find('article',attrs={'class':'normal'})
articles
# Out:
# <article class="normal"><div class="teaser offset"><h2><a href="/news/2022/01/20/164267029250021292.html">यस्तो छ राष्ट्रिय सभा निर्वाचनको स्वास्थ्य सुरक्षा मापदण्ड</a></h2><div class="author"><a href="https://ekantipur.com/author/author-14301">कान्तिपुर संवाददाता</a></div><p>निर्वाचन आयोगले राष्ट्रिय सभा सदस्य निर्वाचनमा स्वास्थ्य सुरक्षा मापदण्ड लागू गरेको छ । माघ १२ गते हुने राष्ट्रिय सभा निर्वाचनमा आयोगले मतदाता, मतदान कर्मचारी, उम्मेदवार, दलका प्रतिनिधि, सुरक्षाकर्मी तथा स्वयंसेवकलगायतलाई लक्षित गरेर २० बुँदे स्वास्थ्य सुरक्षा मापदण्ड अपनाउने भएको हो । </p></div><div class="image"><figure><a href="/news/2022/01/20/164267029250021292.html"><img alt="" data-src="https://assets-cdn-api.kantipurdaily.com/thumb.php?src=https://assets-cdn.kantipurdaily.com/uploads/source/news/kantipur/2021/miscellaneous/election-commision-0432021104835-1000x0.jpg&amp;w=300&amp;h=0"/></a></figure></div><div class="meta-links"><a attr-newsid="9570307" class="saveNewsLink" onclick="saveNews('9570307',thi
# ...

# %%
# article=articles[0]
# article

# %%
base_url = 'https://ekantipur.com/'
article_url = base_url+articles.a['href']

# %%
article_title=articles.a.text
article_title
# Out:
# 'यस्तो छ राष्ट्रिय सभा निर्वाचनको स्वास्थ्य सुरक्षा मापदण्ड'

# %%
article_author=articles.find('div',attrs={'class':'authors'})
article_author

# %%
article_author

# %%
article_ful=articles.p.text
article_ful
# Out:
# 'निर्वाचन आयोगले राष्ट्रिय सभा सदस्य निर्वाचनमा स्वास्थ्य सुरक्षा मापदण्ड लागू गरेको छ\xa0। माघ १२ गते हुने राष्ट्रिय सभा निर्वाचनमा आयोगले मतदाता, मतदान कर्मचारी, उम्मेदवार, दलका प्रतिनिधि, सुरक्षाकर्मी तथा स्वयंसेवकलगायतलाई लक्षित गरेर २० बुँदे स्वास्थ्य सुरक्षा मापदण्ड अपनाउने भएको हो\xa0। '

# %%
soup=BeautifulSoup(news.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
def get_data(soup):
  raw_data=soup.find_all('article',attrs={'class':'normal'})
  master_article=[]
  for articles in raw_data:
    # print(articles)
  

    base_url="https://ekantipur.com/news"
    article_url=base_url+articles.a['text']
    d={}
    d['title']=articles.a.text
    d['author']=articles.find("div",attrs={'class':'author'})
    d['text']=articles.p.text
    d['url']=article_url
    master_article.append(d)
  return(master_article)

# %%
#practising above one
def get_data(soup):
  raw_data=soup.find_all('article',attrs={'class':'normal'})
  for articles in raw_data:
    base_url="https://ekantipur.com/news"
    article_url=base_url+articles.a['text']
    article_url
    d={}
    d['title']=articles.a.text
    d['author']=articles.find("div",attrs={'class':'author'})

# %%
# f=open("samachar.csv","w")
# # f
# Out:
# <_io.TextIOWrapper name='samachar.csv' mode='w' encoding='UTF-8'>

# %%
# with open("samachar","w") as f:
#   f.write()
import csv
def write_file(master_article,i):
  if(i=="news"):
    file="samachar.csv"
  elif(i=="business"):
    file="business.csv"
  elif(i=="opinion"):
    file="opinion.csv"
  else:
    file="sports.csv"
  with open(file,"w")as f:
    file_writer=csv.writer(file)
    a=['title','author','text','url']
    file_writer.writerow(a)
    for article_item in master_article:
      b=article_item.values()
      file_writer.writerow(b)

# %%
master_data = []
dict={'news','business','opinion','sports'}
for i in dict: 
 url = 'https://ekantipur.com/{}'.format(i)
 html_text = articles.text
 soup = articles.text
#  master_data=get_data(soup)
 write_file(master_data,i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5d7140327748> in <module>()
#       6  soup = articles.text
#       7 #  master_data=get_data(soup)
# ----> 8  write_file(master_data,i)
#
# <ipython-input-28-03495949d3d9> in write_file(master_article, i)
#      12     file="sports.csv"
#      13   with open(file,"w")as f:
# ---> 14     file_writer=csv.writer(file)
#      15     a=['title','author','text','url']
#      16     file_writer.writerow(a)
#
# TypeError: argument 1 must have a "write" method

# %% [markdown]
# New style for web scrapping

# %%
master_article=[]
for article in articles:
  d={}
  d['article_url']=base_url+articles.a['href']
  d['title']=articles.a.text
  d['author']=articles.find("div",attrs={'class':'author'})
  d['text']=articles.p.text
  d['url']=article_url
  master_article.append(d)
  return(master_article)
# Out:
#   File "<ipython-input-39-181b188edbc0>", line 10
#     return(master_article)
#     ^
# SyntaxError: 'return' outside function

# %%
import csv

# %%
with open('samachar.csv',"w")as f:
  field_names=data[0].keys()#extract field name-keys
  writer=csv.DictWriter(f,fieldname=fieldnames)
  writer.writeheader()
   for news in data:
     writer.writerow(news)

# %%
list(data[0].keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-efcb516f0f09> in <module>()
# ----> 1 list(data[0].keys())
#
# NameError: name 'data' is not defined
